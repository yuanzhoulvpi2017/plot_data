# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from matplotlib.animation import ArtistAnimation
from matplotlib import animation
from IPython.display import HTML

# %%
# %matplotlib notebook
fig, ax = plt.subplots(figsize=(9, 6))
fig.set_facecolor('gray')
allcolor = ['orange', 'blue', 'orange', 'blue']
_ = ax.pie([1, 1, 1, 1], colors=allcolor, startangle=10,  wedgeprops=dict(width=0.3))
_ = ax.pie([1, 1, 1, 1], colors=allcolor, startangle=10-45,  
           wedgeprops=dict(width=0.006), radius=0.7-0.006)
_ = ax.pie([1, 1, 1, 1], colors=allcolor, startangle=10+45,  
           wedgeprops=dict(width=0.007), radius=1.007)

def animate(angle):
    angle = - angle * 10

    _ = ax.pie([1, 1, 1, 1], colors=allcolor, startangle=angle,  wedgeprops=dict(width=0.3))
    _ = ax.pie([1, 1, 1, 1], colors=allcolor, startangle=angle-45,  
           wedgeprops=dict(width=0.006), radius=0.7-0.006)
    _ = ax.pie([1, 1, 1, 1], colors=allcolor, startangle=angle+45,  
           wedgeprops=dict(width=0.007), radius=1.007)
    print(f"angle: {angle}")



ani = FuncAnimation(fig, animate, frames=72, interval=20)
ani
# ani.save(filename='mypie.mp4')
# plt.show()
from IPython.display import HTML
# HTML(ani.to_html5_video())
# ani.save(filename='mypie.mp4', savefig_kwargs=dict(facecolor='gray'))
ani.save('mypie.gif', writer="pillow", savefig_kwargs=dict(facecolor='gray'))
# Out:
# <img src="data:image/png;base64,..." width="900">
# angle: 0
# angle: 0
# angle: -10
# angle: -20
# angle: -30
# angle: -40
# angle: -50
# angle: -60
# angle: -70
# angle: -80
# angle: -90
# angle: -100
# angle: -110
# angle: -120
# angle: -130
# angle: -140
# angle: -150
# angle: -160
# angle: -170
# angle: -180
# angle: -190
# angle: -200
# angle: -210
# angle: -220
# angle: -230
# angle: -240
# angle: -250
# angle: -260
# angle: -270
# angle: -280
# angle: -290
# angle: -300
# angle: -310
# angle: -320
# angle: -330
# angle: -340
# angle: -350
# angle: -360
# angle: -370
# angle: -380
# angle: -390
# angle: -400
# angle: -410
# angle: -420
# angle: -430
# angle: -440
# angle: -450
# angle: -460
# angle: -470
# angle: -480
# angle: -490
# angle: -500
# angle: -510
# angle: -520
# angle: -530
# angle: -540
# angle: -550
# angle: -560
# angle: -570
# angle: -580
# angle: -590
# angle: -600
# angle: -610
# angle: -620
# angle: -630
# angle: -640
# angle: -650
# angle: -660
# ...

# %%
# %matplotlib notebook
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(9, 6))
fig.set_facecolor('gray')
allcolor = ['#FFCC00', 'blue', '#FFCC00', 'blue']
_ = ax.pie([1, 1, 1, 1], colors=allcolor, startangle=10,  wedgeprops=dict(width=0.3))
_ = ax.pie([1, 1, 1, 1], colors=allcolor, startangle=10-45,  
           wedgeprops=dict(width=0.006), radius=0.7-0.006)
_ = ax.pie([1, 1, 1, 1], colors=allcolor, startangle=10+45,  
           wedgeprops=dict(width=0.007), radius=1.007)

def animate(angle):
    angle = - angle * 10
    _ = ax1.pie([1, 1, 1, 1], colors=allcolor, startangle=angle,  wedgeprops=dict(width=0.3))
    _ = ax1.pie([1, 1, 1, 1], colors=allcolor, startangle=angle-45,  
           wedgeprops=dict(width=0.006), radius=0.7-0.006)
    _ = ax1.pie([1, 1, 1, 1], colors=allcolor, startangle=angle+45,  
           wedgeprops=dict(width=0.007), radius=1.007)
    
    _ = ax2.pie([1, 1, 1, 1], colors=allcolor, startangle=angle,  wedgeprops=dict(width=0.3))
    _ = ax2.pie([1, 1, 1, 1], colors=allcolor, startangle=angle-45,  
           wedgeprops=dict(width=0.006), radius=0.7-0.006)
    _ = ax2.pie([1, 1, 1, 1], colors=allcolor, startangle=angle+45,  
           wedgeprops=dict(width=0.007), radius=1.007)
    print(f"angle: {angle}")




ani = FuncAnimation(fig, animate, frames=72, interval=20)
ani
# ani.save(filename='mypie.mp4')
# plt.show()
from IPython.display import HTML
# HTML(ani.to_html5_video())
# ani.save(filename='mypie.mp4', savefig_kwargs=dict(facecolor='gray'))
ani.save('mypie.gif', writer="pillow", savefig_kwargs=dict(facecolor='gray'))
# Out:
# <img src="data:image/png;base64,..." width="900">
